# %% [markdown]
# ## 0章（線形代数）

# %%
# -*- coding: utf-8 -*-
import numpy as np

# %% [markdown]
# ### 最小二乗法
#     データ：　{x, y: $C_1$}

# %%
# 最小二乗法
def min_seq(x, y):
    x_bar, y_bar = np.mean(x), np.mean(y)
