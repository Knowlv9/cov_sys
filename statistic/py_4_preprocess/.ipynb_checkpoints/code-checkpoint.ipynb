# %%
import numpy as np
import pandas as pd

# %%
filename = "data"
with open(filename, 'r', encoding="utf-8") as f:
    w = f.readlines()

# %%
data = []
head = ['CPU名称', 'Cinebench R15 マルチ', 'コア', 'スレッド', 'TDP', '定格クロック', '最大クロック', '価格']
head
# Out:
# ['CPU名称', 'Cinebench R15 マルチ', 'コア', 'スレッド', 'TDP', '定格クロック', '最大クロック', '価格']
